# %% [markdown]
# ## Question 2 Part 1

# %%
import pandas as pd
from pandas import Series, DataFrame
r = pd.read_csv('C:\\Users\mites\Desktop\PYTHON\Assignment 3\Data\employee_compensation.csv')
r[:10]
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
# 5  Calendar  2016                        2
# 6    Fiscal  2013                        2
# 7  Calendar  2014                        6
# 8  Calendar  2015                        2
# 9    Fiscal  2014                        2
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
# 5   Public Works, Transportation & Commerce             DBI
# 6   Public Works, Transportation & Commerce             DPW
# ...

# %%
frame = DataFrame(r, columns=['Organization Group', 'Department', 'Total Compensation'])
frame[:10]
# Out:
#                          Organization Group  \
# 0   Public Works, Transportation & Commerce
# 1                          Community Health
# 2  Human Welfare & Neighborhood Development
# 3          General Administration & Finance
# 4                      Culture & Recreation
# 5   Public Works, Transportation & Commerce
# 6   Public Works, Transportation & Commerce
# 7          General Administration & Finance
# 8   Public Works, Transportation & Commerce
# 9   Public Works, Transportation & Commerce
#
#                                Department  Total Compensation
# 0                      Airport Commission           143916.66
# 1                           Public Health           107914.16
# 2       Department of the Status of Women              267.28
# 3                         Human Resources             2519.13
# 4          Recreation and Park Commission             1726.68
# 5       Department of Building Inspection           119851.55
# ...

# %%
frame_agg = frame.groupby(['Organization Group','Department'])['Total Compensation'].first()

# %%
frame_agg11 = frame.groupby(['Organization Group','Department']).agg({'Total Compensation':max})

# %%
g = frame_agg11['Total Compensation'].groupby(level=0, group_keys=False)

# %%
res = g.apply(lambda x: x.sort_values(ascending=False)).head(3).to_csv('compensation.csv')
res
# Out:
# Organization Group                        Department
# Community Health                          Public Health                             439541.54
# Culture & Recreation                      Public Library                            336211.56
#                                           Recreation and Park Commission            325435.76
#                                           Asian Art Museum                          294070.96
#                                           War Memorial                              269664.52
#                                           Law Library                               263736.80
#                                           Fine Arts Museum                          263179.38
#                                           Arts Commission                           241829.18
#                                           Academy of Sciences                       190845.44
# ...
