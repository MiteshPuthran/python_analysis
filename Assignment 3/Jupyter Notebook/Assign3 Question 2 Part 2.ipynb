# %% [markdown]
# ## Question 2 Part 2

# %%
import pandas as pd
from pandas import Series, DataFrame
r = pd.read_csv('C:\\Users\mites\Desktop\PYTHON\Assignment 3\Data\employee_compensation.csv')
r[:10]
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
# 5  Calendar  2016                        2
# 6    Fiscal  2013                        2
# 7  Calendar  2014                        6
# 8  Calendar  2015                        2
# 9    Fiscal  2014                        2
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
# 5   Public Works, Transportation & Commerce             DBI
# 6   Public Works, Transportation & Commerce             DPW
# ...

# %%
cal = r.loc[r['Year Type'] == 'Calendar']
for col in cal:
    cal[col].unique()
cal[:10]
# Out:
#    Year Type  Year  Organization Group Code  \
# 0   Calendar  2013                        2
# 2   Calendar  2016                        3
# 3   Calendar  2016                        6
# 5   Calendar  2016                        2
# 7   Calendar  2014                        6
# 8   Calendar  2015                        2
# 10  Calendar  2016                        4
# 13  Calendar  2013                        2
# 14  Calendar  2014                        5
# 15  Calendar  2015                        5
#
#                           Organization Group Department Code  \
# 0    Public Works, Transportation & Commerce             AIR
# 2   Human Welfare & Neighborhood Development             WOM
# 3           General Administration & Finance             HRD
# 5    Public Works, Transportation & Commerce             DBI
# 7           General Administration & Finance             ADM
# 8    Public Works, Transportation & Commerce             AIR
# ...

# %%
frame = DataFrame(cal, columns=['Job Family', 'Total Benefits', 'Total Compensation'])
frame [:10]
# Out:
#                        Job Family  Total Benefits  Total Compensation
# 0                Journeyman Trade        41432.55           143916.66
# 2                      Management           67.28              267.28
# 3                   Legal & Court          736.13             2519.13
# 5   Clerical, Secretarial & Steno        35843.78           119851.55
# 7             Public Service Aide        11956.70            36136.70
# 8          Housekeeping & Laundry        30294.53            94113.95
# 10                 Dietary & Food        32908.84           111084.25
# 13               Journeyman Trade         2367.57             8044.63
# 14     Agriculture & Horticulture        34064.57           117266.41
# 15                     Park & Zoo        28138.44            77617.59

# %%
frame['Percent_Total_Benefit'] = (frame['Total Benefits']/frame['Total Compensation'])*100
# Out:
#                        Job Family  Total Benefits  Total Compensation  \
# 0                Journeyman Trade        41432.55           143916.66
# 2                      Management           67.28              267.28
# 3                   Legal & Court          736.13             2519.13
# 5   Clerical, Secretarial & Steno        35843.78           119851.55
# 7             Public Service Aide        11956.70            36136.70
# 8          Housekeeping & Laundry        30294.53            94113.95
# 10                 Dietary & Food        32908.84           111084.25
# 13               Journeyman Trade         2367.57             8044.63
# 14     Agriculture & Horticulture        34064.57           117266.41
# 15                     Park & Zoo        28138.44            77617.59
#
#     Percent_Total_Benefit
# 0               28.789266
# 2               25.172104
# 3               29.221596
# 5               29.906814
# 7               33.087415
# 8               32.189203
# ...

# %%
frame2 = frame.head(5)
frame2
# Out:
#                       Job Family  Total Benefits  Total Compensation  \
# 0               Journeyman Trade        41432.55           143916.66
# 2                     Management           67.28              267.28
# 3                  Legal & Court          736.13             2519.13
# 5  Clerical, Secretarial & Steno        35843.78           119851.55
# 7            Public Service Aide        11956.70            36136.70
#
#    Percent_Total_Benefit
# 0              28.789266
# 2              25.172104
# 3              29.221596
# 5              29.906814
# 7              33.087415

# %%
frame2.to_csv('compensationbenefits.csv')
