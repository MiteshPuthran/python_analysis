# %% [markdown]
# ## Question 1 Part 2

# %%
import pandas as pd
from pandas import Series, DataFrame
a = pd.read_csv('C:\\Users\mites\Python\DataAnalysis4Python_Spring17\Assignments\Assignment 3\Data\\vehicle_collisions.csv')
a[:10]
# Out:
#    UNIQUE KEY    DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0     3146911  1/1/15   0:20     QUEENS   11358.0  40.751847 -73.787862
# 1     3146180  1/1/15   0:20        NaN       NaN  40.771289 -73.946693
# 2     3146384  1/1/15   0:21   BROOKLYN   11205.0  40.689445 -73.955121
# 3     3146013  1/1/15   0:30   BROOKLYN   11213.0  40.673845 -73.925080
# 4     3146120  1/1/15   0:33        NaN       NaN        NaN        NaN
# 5     3145968  1/1/15   0:51   BROOKLYN   11203.0  40.656684 -73.929896
# 6     3146102  1/1/15  10:00     QUEENS   11105.0  40.776519 -73.915920
# 7     3146344  1/1/15  10:05   BROOKLYN   11203.0  40.657281 -73.947354
# 8     3145900  1/1/15  10:06  MANHATTAN   10024.0  40.787223 -73.967926
# 9     3145960  1/1/15  10:10   BROOKLYN   11223.0  40.593323 -73.964638
#
#                     LOCATION    ON STREET NAME   CROSS STREET NAME  \
# 0   (40.7518471, -73.787862)         47 AVENUE          193 STREET
# ...

# %%
a.BOROUGH.unique()
# Out:
# array(['QUEENS', nan, 'BROOKLYN', 'MANHATTAN', 'BRONX', 'STATEN ISLAND'], dtype=object)

# %%
frame2 = DataFrame(a, columns=['BOROUGH', 'VEHICLE 1 TYPE', 'VEHICLE 2 TYPE', 'VEHICLE 3 TYPE','VEHICLE 4 TYPE', 'VEHICLE 5 TYPE'])
frame2[:10]
# Out:
#      BOROUGH               VEHICLE 1 TYPE               VEHICLE 2 TYPE  \
# 0     QUEENS  SPORT UTILITY/STATION WAGON                          NaN
# 1        NaN            PASSENGER VEHICLE                          NaN
# 2   BROOKLYN            PASSENGER VEHICLE                      UNKNOWN
# 3   BROOKLYN                          BUS            PASSENGER VEHICLE
# 4        NaN                      UNKNOWN            PASSENGER VEHICLE
# 5   BROOKLYN            PASSENGER VEHICLE  SPORT UTILITY/STATION WAGON
# 6     QUEENS            PASSENGER VEHICLE            PASSENGER VEHICLE
# 7   BROOKLYN            PASSENGER VEHICLE            PASSENGER VEHICLE
# 8  MANHATTAN            PASSENGER VEHICLE                          NaN
# 9   BROOKLYN            PASSENGER VEHICLE            PASSENGER VEHICLE
#
#                 VEHICLE 3 TYPE     VEHICLE 4 TYPE VEHICLE 5 TYPE
# 0                          NaN                NaN            NaN
# ...

# %%
frame2 = frame2.rename(columns={'VEHICLE 1 TYPE': 'One_Vehicle_Involved', 'VEHICLE 2 TYPE': 'Two_Vehicle_Involved','VEHICLE 3 TYPE': 'Three_Vehicle_Involved','VEHICLE 4 TYPE': 'Four_Vehicle_Involved','VEHICLE 5 TYPE': 'Five_Vehicle_Involved'})
frame2.groupby('BOROUGH')['One_Vehicle_Involved','Two_Vehicle_Involved','Three_Vehicle_Involved','Four_Vehicle_Involved','Five_Vehicle_Involved'].count().to_csv('vehicle.csv')
# Out:
#            One_Vehicle_Involved  Two_Vehicle_Involved  Three_Vehicle_Involved  \
# BOROUGH
# BRONX                     45599                 36972                    2587
# BROOKLYN                 104174                 86799                    6592
# MANHATTAN                 82801                 69483                    2525
#
#            Four_Vehicle_Involved  Five_Vehicle_Involved
# BOROUGH
# BRONX                        625                    173
# BROOKLYN                    1612                    461
# MANHATTAN                    501                    129
